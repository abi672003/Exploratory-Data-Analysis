# %% [markdown]
# <a href="https://colab.research.google.com/github/abi672003/Exploratory-Data-Analysis/blob/main/PERFORMING_EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive

# %%
import pandas as pd
vg_df = pd.read_csv('/content/Video_Games_Sales_as_at_22_Dec_2016.csv')
vg_df
# Out:
#                                 Name Platform  Year_of_Release         Genre  \
# 0                         Wii Sports      Wii           2006.0        Sports
# 1                  Super Mario Bros.      NES           1985.0      Platform
# 2                     Mario Kart Wii      Wii           2008.0        Racing
# 3                  Wii Sports Resort      Wii           2009.0        Sports
# 4           Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing
# ...                              ...      ...              ...           ...
# 16714  Samurai Warriors: Sanada Maru      PS3           2016.0        Action
# 16715               LMA Manager 2007     X360           2006.0        Sports
# 16716        Haitaka no Psychedelica      PSV           2016.0     Adventure
# 16717               Spirits & Spells      GBA           2003.0      Platform
# 16718            Winning Post 8 2016      PSV           2016.0    Simulation
#
# ...

# %%
vg_df.describe()
# Out:
#        Year_of_Release      NA_Sales      EU_Sales      JP_Sales  \
# count     16450.000000  16719.000000  16719.000000  16719.000000
# mean       2006.487356      0.263330      0.145025      0.077602
# std           5.878995      0.813514      0.503283      0.308818
# min        1980.000000      0.000000      0.000000      0.000000
# 25%        2003.000000      0.000000      0.000000      0.000000
# 50%        2007.000000      0.080000      0.020000      0.000000
# 75%        2010.000000      0.240000      0.110000      0.040000
# max        2020.000000     41.360000     28.960000     10.220000
#
#         Other_Sales  Global_Sales  Critic_Score  Critic_Count    User_Count
# count  16719.000000  16719.000000   8137.000000   8137.000000   7590.000000
# mean       0.047332      0.533543     68.967679     26.360821    162.229908
# std        0.186710      1.547935     13.938165     18.980495    561.282326
# min        0.000000      0.010000     13.000000      3.000000      4.000000
# ...

# %%
import seaborn as sns
sns.histplot(x='User_Count', data=vg_df)
# Out:
# <Axes: xlabel='User_Count', ylabel='Count'>

# %%
import matplotlib.pyplot as plt

cols = 3
rows = 3
num_cols = vg_df.select_dtypes(exclude='object').columns
fig = plt.figure( figsize=(cols*5, rows*5))
for i, col in enumerate(num_cols):

    ax=fig.add_subplot(rows,cols,i+1)

    sns.histplot(x = vg_df[col], ax = ax)

fig.tight_layout()
plt.show()

# %%
sns.kdeplot(x='Global_Sales', data=vg_df, hue='Genre')
# Out:
# <Axes: xlabel='Global_Sales', ylabel='Density'>

# %%
sns.histplot(x='Genre', data=vg_df, kde=True)
# Out:
# <Axes: xlabel='Genre', ylabel='Count'>

# %%
sns.boxplot(x=vg_df['EU_Sales'])
# Out:
# <Axes: xlabel='EU_Sales'>

# %%
sns.boxplot(data=vg_df.loc[:, ['NA_Sales', 'Global_Sales']])
# Out:
# <Axes: >

# %%
cols = 3
rows = 3
num_cols = vg_df.select_dtypes(exclude='object').columns
fig = plt.figure(figsize= (15,9))
for i, col in enumerate(num_cols):

    ax=fig.add_subplot( rows, cols, i+1)

    sns.boxplot(x=vg_df[col], ax=ax)

fig.tight_layout()
plt.show()

# %%
sns.violinplot(x=vg_df["Critic_Score"])
# Out:
# <Axes: xlabel='Critic_Score'>

# %%
sns.stripplot(x=vg_df["NA_Sales"]);

# %%
vg_df.describe(include='object')
# Out:
#                                Name Platform   Genre        Publisher  \
# count                         16717    16719   16717            16665
# unique                        11562       31      12              581
# top     Need for Speed: Most Wanted      PS2  Action  Electronic Arts
# freq                             12     2161    3370             1356
#
#        User_Score Developer Rating
# count       10015     10096   9950
# unique         96      1696      8
# top           tbd   Ubisoft      E
# freq         2425       204   3991

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10,10))
ax=sns.countplot(x=vg_df.Rating)

# %%
plt.pie(pdf, labels=pdf.index, autopct="%.0f%%");
plt.show()

# %%
meandf = vg_df['Global_Sales'].mean()
meandf
# Out:
# 0.5335426759973684

# %%
modedf =vg_df['Global_Sales'].mode()
modedf
# Out:
# 0    0.02
# Name: Global_Sales, dtype: float64

# %%
SD=vg_df['Global_Sales'].std()
SD
# Out:
# 1.547935124717767

# %%
sns.distplot(vg_df.User_Count)
# Out:
# <ipython-input-29-2ca59349eca6>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(vg_df.User_Count)
# <Axes: xlabel='User_Count', ylabel='Density'>

# %%
import math
import numpy as np
import pandas as pd
from matplotlib import pyplot
from scipy import stats
mu, sigma = 128, 25 # From the above example
highest_Credits = np.random.normal(mu, sigma, 1000) # Random 1000 values

count, bins, _ = pyplot.hist(highest_Credits, 100, color='lightpink')# plot 100 points
pyplot.plot(bins, 1/(sigma * np.sqrt(2 * np.pi)) *
    np.exp( - (bins - mu)**2 / (2 * sigma**2) ),
    linewidth = 2, color = 'r')

# %%
sns.heatmap(vg_df.corr())
plt.show()
# Out:
# <ipython-input-32-ba80e2fce8d8>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(vg_df.corr())

# %%
vg_df[["User_Count","Global_Sales"]].corr()
# Out:
#               User_Count  Global_Sales
# User_Count      1.000000      0.265012
# Global_Sales    0.265012      1.000000

# %%
plt.scatter(vg_df.User_Count,vg_df.Global_Sales)
plt.xlabel("User_Count")
plt.ylabel("Global_Sales")
plt.show()

# %%
sns.pairplot(vg_df, kind="scatter",hue='Year_of_Release')
plt.show()

# %% [markdown]
# **UNIVARIENT**

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list the files in the input directory


# Any results you write to the current directory are saved as output.

#For plotting
from matplotlib import pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
vg_df = pd.read_csv('/content/drive/MyDrive/Video_Games_Sales_as_at_22_Dec_2016.csv')

# %%
print('This dataset has ' + str(vg_df.shape[0]) + ' rows, and ' + str(vg_df.shape[1]) + ' columns')
# Out:
# This dataset has 16719 rows, and 16 columns

# %%
vg_df.head(5)
# Out:
#                        Name Platform  Year_of_Release         Genre Publisher  \
# 0                Wii Sports      Wii           2006.0        Sports  Nintendo
# 1         Super Mario Bros.      NES           1985.0      Platform  Nintendo
# 2            Mario Kart Wii      Wii           2008.0        Racing  Nintendo
# 3         Wii Sports Resort      Wii           2009.0        Sports  Nintendo
# 4  Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  Critic_Score  \
# 0     41.36     28.96      3.77         8.45         82.53          76.0
# 1     29.08      3.58      6.81         0.77         40.24           NaN
# 2     15.68     12.76      3.79         3.29         35.52          82.0
# 3     15.61     10.93      3.28         2.95         32.77          80.0
# 4     11.27      8.89     10.22         1.00         31.37           NaN
#
#    Critic_Count User_Score  User_Count Developer Rating
# ...

# %%
vg_df.describe()
# Out:
#        Year_of_Release      NA_Sales      EU_Sales      JP_Sales  \
# count     16450.000000  16719.000000  16719.000000  16719.000000
# mean       2006.487356      0.263330      0.145025      0.077602
# std           5.878995      0.813514      0.503283      0.308818
# min        1980.000000      0.000000      0.000000      0.000000
# 25%        2003.000000      0.000000      0.000000      0.000000
# 50%        2007.000000      0.080000      0.020000      0.000000
# 75%        2010.000000      0.240000      0.110000      0.040000
# max        2020.000000     41.360000     28.960000     10.220000
#
#         Other_Sales  Global_Sales  Critic_Score  Critic_Count    User_Count
# count  16719.000000  16719.000000   8137.000000   8137.000000   7590.000000
# mean       0.047332      0.533543     68.967679     26.360821    162.229908
# std        0.186710      1.547935     13.938165     18.980495    561.282326
# min        0.000000      0.010000     13.000000      3.000000      4.000000
# ...

# %% [markdown]
# Year of Release

# %%
sns.distplot(vg_df.Year_of_Release.dropna(), kde=False, bins = 39);
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# Global Sales

# %%
Global_Salesfig, axs = plt.subplots(ncols = 4, figsize=(13, 4))

sns.distplot(vg_df.Global_Sales.dropna(), kde=False, ax=axs[0])
second_plt = sns.distplot(vg_df.Global_Sales.dropna()[vg_df.Global_Sales > 2], kde=False, ax=axs[1])
sns.boxplot(vg_df.Global_Sales, ax=axs[2], orient = 'v')
sns.boxplot(vg_df.Global_Sales, ax=axs[3], orient = 'v', showfliers=False)

second_plt.set_yscale('log')
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/seaborn/_core.py:1326: UserWarning: Vertical orientation ignored with only `x` specified.
#   warnings.warn(single_var_warning.format("Vertical", "x"))
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/seaborn/_core.py:1326: UserWarning: Vertical orientation ignored with only `x` specified.
# ...

# %% [markdown]
# North America

# %%
Global_Salesfig, axs = plt.subplots(ncols = 4, figsize=(13, 4))

sns.distplot(vg_df.NA_Sales.dropna(), kde=False, ax=axs[0])
second_plt = sns.distplot(vg_df.NA_Sales.dropna()[vg_df.NA_Sales > 1], kde=False, ax=axs[1])
sns.boxplot(vg_df.NA_Sales, ax=axs[2], orient = 'v')
sns.boxplot(vg_df.NA_Sales, ax=axs[3], orient = 'v', showfliers=False)

second_plt.set_yscale('log')
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/seaborn/_core.py:1326: UserWarning: Vertical orientation ignored with only `x` specified.
#   warnings.warn(single_var_warning.format("Vertical", "x"))
# ...

# %% [markdown]
# European Union

# %%
Global_Salesfig, axs = plt.subplots(ncols = 4, figsize=(13, 4))

sns.distplot(vg_df.EU_Sales.dropna(), kde=False, ax=axs[0])
second_plt = sns.distplot(vg_df.EU_Sales.dropna()[vg_df.EU_Sales > 1], kde=False, ax=axs[1])
sns.boxplot(vg_df.EU_Sales, ax=axs[2], orient = 'v')
sns.boxplot(vg_df.EU_Sales, ax=axs[3], orient = 'v', showfliers=False)

second_plt.set_yscale('log')
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/seaborn/_core.py:1326: UserWarning: Vertical orientation ignored with only `x` specified.
#   warnings.warn(single_var_warning.format("Vertical", "x"))
# ...

# %% [markdown]
# Japan

# %%
Global_Salesfig, axs = plt.subplots(ncols = 4, figsize=(13, 4))

sns.distplot(vg_df.JP_Sales.dropna(), kde=False, ax=axs[0])
second_plt = sns.distplot(vg_df.JP_Sales.dropna()[vg_df.JP_Sales > 1], kde=False, ax=axs[1])
sns.boxplot(vg_df.JP_Sales, ax=axs[2], orient = 'v')
sns.boxplot(vg_df.JP_Sales, ax=axs[3], orient = 'v', showfliers=False)

second_plt.set_yscale('log')
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/seaborn/_core.py:1326: UserWarning: Vertical orientation ignored with only `x` specified.
#   warnings.warn(single_var_warning.format("Vertical", "x"))
# ...

# %% [markdown]
# Rest of the World

# %%
Global_Salesfig, axs = plt.subplots(ncols = 4, figsize=(13, 4))

sns.distplot(vg_df.Other_Sales.dropna(), kde=False, ax=axs[0])
second_plt = sns.distplot(vg_df.Other_Sales.dropna()[vg_df.Other_Sales > 1], kde=False, ax=axs[1])
sns.boxplot(vg_df.Other_Sales, ax=axs[2], orient = 'v')
sns.boxplot(vg_df.Other_Sales, ax=axs[3], orient = 'v', showfliers=False)

second_plt.set_yscale('log')
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/seaborn/_core.py:1326: UserWarning: Vertical orientation ignored with only `x` specified.
#   warnings.warn(single_var_warning.format("Vertical", "x"))
# ...

# %% [markdown]
# Games Evaluation

# %%
sns.distplot(vg_df.Critic_Score.dropna());
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# Critic Count

# %%
sns.distplot(vg_df.Critic_Count.dropna());

# %% [markdown]
# Categorical Variables

# %%
plt.figure(figsize=(13, 4))

sns.countplot(vg_df.Platform.dropna(), order = vg_df.Platform.value_counts().index);
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# Genre

# %%
plt.figure(figsize=(13, 4))
sns.countplot(vg_df.Genre.dropna(), order = vg_df.Genre.value_counts().index);
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# Developer

# %%
plt.figure(figsize=(13, 4))
sns.countplot(vg_df.Developer.dropna(), order = vg_df.Developer.value_counts().index);
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
plt.figure(figsize=(13, 4))
sns.countplot(vg_df.Developer.dropna(), order = vg_df.Developer.value_counts().iloc[:40].index)
plt.xticks(rotation=90);
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
import seaborn as sns
sns.histplot(x='Critic_Score', data=vg_df)

# %%
# to create individual histograms for all numeric variables.
import matplotlib.pyplot as plt

cols = 3
rows = 3
num_cols = vg_df.select_dtypes(exclude='object').columns
fig = plt.figure( figsize=(cols*5, rows*5))
for i, col in enumerate(num_cols):

    ax=fig.add_subplot(rows,cols,i+1)

    sns.histplot(x = vg_df[col], ax = ax)

fig.tight_layout()
plt.show()

# %%
# kernel density estimate
# The ‘kernel density estimate’ plot creates a smooth version of a histogram by normalizing all points to appear under one curve.

sns.kdeplot(x='Year_of_Release', data=vg_df)

# %%
# KDE with Histogram plot — sns.histplot(kde=True)

# We can display a histogram with a KDE curve as below. See this post for an understanding of kde and histogram


sns.histplot(x='Genre', data=vg_df, kde=True)

# %%
# Box plots — sns.boxplot()

# A boxplot shows the distribution, center and skewness of a numeric feature.
# It divides the data into sections that contain 25% of the data approximately.

sns.boxplot(x=vg_df['Year_of_Release'])

# %%
# to compare the distribution of two columns that are related

sns.boxplot(data=vg_df.loc[:, ['Year_of_Release', 'Critic_Score']])

# %%
cols = 3
rows = 3
num_cols = vg_df.select_dtypes(exclude='object').columns
fig = plt.figure(figsize= (15,9))
for i, col in enumerate(num_cols):

    ax=fig.add_subplot( rows, cols, i+1)

    sns.boxplot(x=vg_df[col], ax=ax)

fig.tight_layout()
plt.show()

# %% [markdown]
# **BIVARIENT**

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive

# %%
sns.heatmap(vg_df.corr())
plt.show()

# %% [markdown]
# Correlation between two numeric features
#
# 1. High negative correlation

# %%
vg_df[["NA_Sales","EU_Sales"]].corr()
# Out:
#           NA_Sales  EU_Sales
# NA_Sales  1.000000  0.765336
# EU_Sales  0.765336  1.000000
